# %% [markdown]
# ## MODELO 1

# %% [markdown]
# ##### TREINAR O MODELO

# %%
import re
import spacy
from gensim.models import Word2Vec

nlp = spacy.load("pt_core_news_sm")


ficheiros = [
    "Harry Potter e A Pedra Filosofal.txt", 
    "Harry_Potter_Camara_Secreta-br.txt"
]

sentences = []

for nome_ficheiro in ficheiros:
    print(f"A processar o ficheiro: {nome_ficheiro}...")
    
    with open(nome_ficheiro, "r", encoding="utf8") as f:
        texto = f.read()
        
        texto = re.sub(r'\f', '', texto)
        
        doc = nlp(texto)
        
        for sent in doc.sents:
            tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
            if len(tokens) > 0:
                sentences.append(tokens)


print(f"Total de frases carregadas: {len(sentences)}")
model = Word2Vec(sentences, vector_size=150, window=5, min_count=2, sg=0, epochs=20, workers=3)
# Out:
# A processar o ficheiro: Harry Potter e A Pedra Filosofal.txt...
# A processar o ficheiro: Harry_Potter_Camara_Secreta-br.txt...
# Total de frases carregadas: 14610

# %%
model.wv.save_word2vec_format('model_harry.txt',binary=False)
#projector.tensorflow.org

# %%
# !python -m gensim.scripts.word2vec2tensor -i model_harry.txt -o model_harry
# Out:
# 2026-04-28 16:26:59,042 - word2vec2tensor - INFO - running c:\Users\laura\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\scripts\word2vec2tensor.py -i model_harry.txt -o model_harry
# 2026-04-28 16:26:59,043 - keyedvectors - INFO - loading projection weights from model_harry.txt
# 2026-04-28 16:27:01,368 - utils - INFO - KeyedVectors lifecycle event {'msg': 'loaded (6989, 150) matrix of type float32 from model_harry.txt', 'binary': False, 'encoding': 'utf8', 'datetime': '2026-04-28T16:27:01.342573', 'gensim': '4.4.0', 'python': '3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26200-SP0', 'event': 'load_word2vec_format'}
# 2026-04-28 16:27:02,964 - word2vec2tensor - INFO - 2D tensor file saved to model_harry_tensor.tsv
# 2026-04-28 16:27:02,964 - word2vec2tensor - INFO - Tensor metadata file saved to model_harry_metadata.tsv
# 2026-04-28 16:27:02,965 - word2vec2tensor - INFO - finished running word2vec2tensor.py

# %%
len(model.wv)
# Out:
# 6989

# %%
model.wv.index_to_key
# Out:
# ['de',
#  'que',
#  'a',
#  'e',
#  'o',
#  'harry',
#  'não',
#  'para',
#  'um',
#  'se',
#  'uma',
#  'os',
#  'com',
#  'do',
#  'em',
#  'ele',
#  'da',
#  'disse',
#  'é',
#  'no',
#  'rony',
#  'na',
#  'você',
#  'mas',
#  'por',
#  'as',
#  'mais',
#  'estava',
#  'como',
#  'quando',
#  'eu',
#  'era',
#  'à',
#  'ao',
#  'muito',
#  'foi',
#  'hagrid',
#  'está',
#  'dos',
#  'coisa',
#  'hermione',
#  'sua',
#  'me',
#  'seu',
#  'eles',
#  'ela',
#  'bem',
#  'das',
#  'cabeça',
#  'olhos',
#  'isso',
#  'até',
#  'dumbledore',
#  'tinha',
#  'vez',
#  'perguntou',
#  'ter',
#  '=',
#  'sem',
#  'então',
#  'vai',
#  'só',
#  'ser',
#  'agora',
#  'snape',
#  'porta',
#  'potter',
#  'já',
#  'pelo',
#  'weasley',
#  'parecia',
#  'dois',
#  'fazer',
#  'vocês',
#  'nada',
#  'lockhart',
#  'voz',
#  'depois',
#  'dizer',
#  'todos',
#  'lhe',
#  'vamos',
#  'nunca',
#  'havia',
#  'alguma',
#  'seus',
#  'aqui',
#  'tão',
#  'pela',
#  'nem',
#  'dele',
#  'sr.',
#  'draco',
#  'fora',
#  'lado',
#  'nos',
#  'quase',
#  'estavam',
#  'mesmo',
#  'ainda',
#  'sala',
#  'tem',
#  'ver',
#  'grifinória',
#  'tempo',
#  'ah',
#  'quem',
#  'casa',
#  'tinham',
#  'porque',
#  'meu',
#  'sobre',
#  'onde',
#  'enquanto',
#  'grande',
#  'varinha',
#  'hogwarts',
#  'escola',
#  'duda',
#  'malfoy',
#  'tudo',
#  'antes',
#  'viu',
#  'senhor',
#  'sabe',
#  'outra',
#  'também',
#  'rosto',
#  'profa',
#  'ou',
#  'alunos',
#  'tio',
#  'todo',
#  'volta',
#  'deu',
#  'chão',
#  'lá',
#  'mione',
#  'válter',
#  'mão',
#  'cima',
#  'vou',
#  'dia',
#  'alto',
#  'dobby',
#  'neville',
#  'respondeu',
#  'melhor',
#  'ficou',
#  'alguém',
#  'dursley',
#  'depressa',
#  'fred',
#  'cara',
#  'fez',
#  'três',
#  'ninguém',
#  'hora',
#  'noite',
#  'frente',
#  'pode',
#  'riddle',
#  'acho',
#  'dentro',
#  'minha',
#  'sonserina',
#  'nas',
#  'sempre',
#  'carro',
#  'bom',
#  'jorge',
#  'gina',
#  'estar',
#  'aos',
#  'estou',
#  'falar',
#  'outro',
#  'olhar',
#  'sei',
#  'isto',
#  'pessoas',
#  'madame',
#  'pedra',
#  'filch',
#  'às',
#  'cada',
#  'ano',
#  'tivesse',
#  'quirrell',
#  'prof',
#  'ia',
#  'percy',
#  'lugar',
#  'saiu',
#  'meio',
#  'pouco',
#  'mesa',
#  'gritou',
#  'exclamou',
#  'talvez',
#  'tentando',
#  'começou',
#  'claro',
#  'direção',
#  'suas',
#  'quadribol',
#  'ar',
#  'falou',
#  'primeiro',
#  'fazendo',
#  'câmara',
#  'ali',
#  'dar',
#  'sra.',
#  'olhou',
#  'atrás',
#  'livros',
#  'toda',
#  'corredor',
#  'podia',
#  'ficar',
#  'num',
#  'assim',
#  'repente',
#  'garoto',
#  'vassoura',
#  'poderia',
#  'sabia',
#  'coisas',
#  'mundo',
#  'tenho',
#  'são',
#  'trouxas',
#  'nós',
#  'professor',
#  'boca',
#  'capa',
#  'chapéu',
#  'bruxo',
#  'estão',
#  'minerva',
#  'sido',
#  'embora',
#  'entre',
#  'vão',
#  'quero',
#  'cabelos',
#  'deles',
#  'vezes',
#  'aula',
#  'outros',
#  'contra',
#  'quanto',
#  'tia',
#  'gente',
#  'foram',
#  'eram',
#  'ouviu',
#  'mãos',
#  'teve',
#  'ir',
#  'cama',
#  'certeza',
#  'diário',
#  'petúnia',
#  'há',
#  'saber',
#  'hoje',
#  'menos',
#  'qualquer',
#  'magia',
#  'correndo',
#  'aí',
#  'pai',
#  'nome',
#  'pessoa',
#  'bruxos',
#  'teria',
#  'deve',
#  'passar',
#  'fosse',
#  'primeira',
#  'livro',
#  'mal',
#  'trás',
#  'seguinte',
#  'finalmente',
#  'abriu',
#  'duas',
#  'castelo',
#  'entrar',
#  'olhando',
#  'anos',
#  'parede',
#  'queria',
#  'caminho',
#  'mim',
#  'pelos',
#  'vida',
#  'numa',
#  'devia',
#  'temos',
#  'vestes',
#  'quer',
#  'tentou',
#  'realmente',
#  'aquela',
#  'logo',
#  'janela',
#  'segundo',
#  'carta',
#  'mcgonagall',
#  'voltar',
#  'nariz',
#  'será',
#  'sorriso',
#  'murta',
#  'força',
#  'família',
#  'espelho',
#  'sair',
#  'nenhum',
#  'time',
#  'uns',
#  'acha',
#  'bateu',
#  'parou',
#  'aquele',
#  'instante',
#  'tanto',
#  'sentiu',
#  'momento',
#  'menino',
#  'novo',
#  'tenha',
#  'manhã',
#  'minutos',
#  'conseguiu',
#  'pensar',
#  'floresta',
#  'quarto',
#  'posso',
#  'este',
#  'deixou',
#  'durante',
#  'salão',
#  'cobra',
#  'braço',
#  'voldemort',
#  'professora',
#  'passou',
#  'rua',
#  'cinco',
#  'goyle',
#  'pontos',
#  'sangue',
#  'mãe',
#  'seguida',
#  'alta',
#  'demais',
#  'essa',
#  'contar',
#  'luz',
#  'pés',
#  'silêncio',
#  'algum',
#  'quatro',
#  'pirraça',
#  'tom',
#  'seria',
#  'verdade',
#  'entrou',
#  'coruja',
#  'garotos',
#  'enorme',
#  'pé',
#  'apenas',
#  'caiu',
#  'murmurou',
#  'andar',
#  'olívio',
#  'secreta',
#  'sou',
#  'ouviram',
#  'continuou',
#  'estivesse',
#  'deixar',
#  'fazia',
#  'wood',
#  'favor',
#  'rúbeo',
#  'aconteceu',
#  'dando',
#  'baixo',
#  'todas',
#  'ouvir',
#  'encontrar',
#  'fogo',
#  'tarde',
#  'ideia',
#  'pensou',
#  'capítulo',
#  'crabbe',
#  'professores',
#  'atenção',
#  'escada',
#  'diante',
#  'banheiro',
#  'dela',
#  'desde',
#  'alguns',
#  'dez',
#  'corpo',
#  'mesma',
#  'chegar',
#  'disso',
#  'continuava',
#  'velho',
#  'pelas',
#  'naquele',
#  'slytherin',
#  'teto',
#  'difícil',
#  'história',
#  'poder',
#  'fim',
#  'nick',
#  'falando',
#  'pudesse',
#  'escuro',
#  'sim',
#  'chegou',
#  'parte',
#  'trem',
#  'pena',
#  'puxou',
#  'voltou',
#  'quê',
#  'pareceu',
#  'horas',
#  'costas',
#  'virou',
#  'maior',
#  'poção',
#  'olhe',
#  'amigos',
#  'armário',
#  'levantou',
#  'pernas',
#  'razão',
#  'seja',
#  'jogo',
#  'feitiço',
#  'feito',
#  'dizendo',
#  'modo',
#  'muita',
#  'tirou',
#  'canino',
#  'granger',
#  'dragão',
#  'cheio',
#  'boa',
#  'pareciam',
#  'ergueu',
#  'óculos',
#  'vira',
#  'balaço',
#  'trevas',
#  'cair',
#  'entrada',
#  'desapareceu',
#  'tornou',
#  'perto',
#  'esse',
#  'última',
#  'preciso',
#  'grandes',
#  'conseguia',
#  'jeito',
#  'ponta',
#  'achou',
#  'parar',
#  'nosso',
#  'colin',
#  'trasgo',
#  'saíram',
#  'biblioteca',
#  'caso',
#  'contou',
#  'certo',
#  'pomfrey',
#  'parecendo',
#  'esperando',
#  'levou',
#  'comprar',
#  'meia',
#  'comunal',
#  'poções',
#  'natal',
#  'aranhas',
#  'sob',
#  'matar',
#  'exatamente',
#  'medo',
#  'palavras',
#  'bruxas',
#  'campo',
#  'umas',
#  'cartas',
#  'lareira',
#  'ombro',
#  'sorte',
#  'mulher',
#  'longe',
#  'pensando',
#  'paredes',
#  'expressão',
#  'justino',
#  'aulas',
#  'mamãe',
#  'testa',
#  'qual',
#  'correu',
#  'andando',
#  'vista',
#  'vassouras',
#  'caldeirão',
#  'feitiços',
#  'tentar',
#  'entraram',
#  'forte',
#  'cadeira',
#  'ficaram',
#  'procurando',
#  'agarrou',
#  'dedos',
#  'homem',
#  'acrescentou',
#  'principal',
#  'estamos',
#  'amigo',
#  'berrou',
#  'pais',
#  'virou-se',
#  'nervoso',
#  'raiva',
#  'apanhou',
#  'descobrir',
#  'esta',
#  'nossa',
#  'simas',
#  'canto',
#  'perguntar',
#  'faz',
#  'querer',
#  'trabalho',
#  'soltou',
#  'braços',
#  'parece',
#  'acontecendo',
#  'último',
#  'gilderoy',
#  'fantasma',
#  'casas',
#  'gringotes',
#  'houve',
#  'sozinho',
#  'levar',
#  'sol',
#  'passado',
#  'feliz',
#  'precisa',
#  'porém',
#  'possível',
#  'nenhuma',
#  'cinquenta',
#  'lufa-lufa',
#  'direto',
#  'gostaria',
#  'banco',
#  'menor',
#  'ruído',
#  'única',
#  'encontrou',
#  'apareceu',
#  'coração',
#  'têm',
#  'parado',
#  'jamais',
#  'começar',
#  'imediatamente',
#  'tirar',
#  'furioso',
#  'cheia',
#  'pior',
#  'veio',
#  'inteira',
#  'rápido',
#  'cachorro',
#  'viram',
#  'chá',
#  'sentado',
#  'obrigado',
#  'elfo',
#  'festa',
#  'pomo',
#  'nor-r-ra',
#  'edwiges',
#  'cuidado',
#  'fundo',
#  'dor',
#  'embaixo',
#  'barulho',
#  'loja',
#  'vinha',
#  'vendo',
#  'cozinha',
#  'espero',
#  'acima',
#  'famoso',
#  'bolso',
#  'palavra',
#  'ler',
#  'podiam',
#  'basilisco',
#  'cochichou',
#  'passos',
#  'mágica',
#  'cor',
#  'salto',
#  'papai',
#  'resto',
#  'pequeno',
#  'tamanho',
#  'apontando',
#  'iria',
#  'meus',
#  'hum',
#  'voando',
#  'muitos',
#  'diretor',
#  'estranha',
#  'desta',
#  'flitwick',
#  'torre',
#  'dormitório',
#  'fofo',
#  'gêmeos',
#  'cabeças',
#  'ansioso',
#  'lados',
#  'comentou',
#  'chocolate',
#  'férias',
#  'classe',
#  'podem',
#  'cicatriz',
#  'podemos',
#  'horrível',
#  'semana',
#  'provavelmente',
#  'pôde',
#  'gato',
#  'própria',
#  'fawkes',
#  'herdeiro',
#  'perder',
#  'comigo',
#  'passaram',
#  'aberta',
#  'tomar',
#  'junto',
#  'outras',
#  'água',
#  'suficiente',
#  'chegaram',
#  'ruim',
#  'vermelho',
#  'mandou',
#  'aniversário',
#  'lembrar',
#  'vir',
#  'aposto',
#  'esperar',
#  'sorrindo',
#  'acabara',
#  'segundos',
#  'aquilo',
#  'estranho',
#  'céu',
#  'sete',
#  'seis',
#  'lúcio',
#  'saguão',
#  'aluno',
#  'tanta',
#  'sapo',
#  'dias',
#  'sentia',
#  'explicou',
#  'apanhar',
#  'ficando',
#  'abrir',
#  'problema',
#  'ouro',
#  'próximo',
#  'corujas',
#  'nove',
#  'mostrar',
#  'árvores',
#  'jogadores',
#  'garota',
#  'flamel',
#  'usar',
#  'si',
#  'portas',
#  'comer',
#  'longo',
#  'lentamente',
#  'muitas',
#  'debaixo',
#  'procurar',
#  'prata',
#  'jantar',
#  'você-sabe-quem',
#  'ouvi',
#  'algumas',
#  'exceto',
#  'acreditar',
#  'forma',
#  'norberto',
#  'pediu',
#  'carlinhos',
#  'dentes',
#  'vinte',
#  'verde',
#  'nele',
#  'sussurrou',
#  'vontade',
#  'vá',
#  'afinal',
#  'completamente',
#  'elas',
#  'número',
#  'reparou',
#  'enormes',
#  'tipo',
#  'língua',
#  'papel',
#  'ernie',
#  'partida',
#  'escuridão',
#  'corredores',
#  'monitor',
#  'ouviu-se',
#  'longa',
#  'caixa',
#  'janelas',
#  'envelope',
#  'acabado',
#  'começaram',
#  'baixinho',
#  'querido',
#  'meninos',
#  'precisava',
#  'pergunta',
#  'conta',
#  'inteiro',
#  'sinal',
#  'bastante',
#  'frio',
#  'orelhas',
#  'estivera',
#  'vi',
#  'trouxa',
#  'achava',
#  'percebeu',
#  'pescoço',
#  'presente',
#  'monstro',
#  'voar',
#  'morto',
#  'ouvido',
#  'plataforma',
#  'jogar',
#  'nimbus',
#  'mágicas',
#  'bruxa',
#  'aonde',
#  'café',
#  'leu',
#  'apontou',
#  'bater',
#  'grito',
#  'importante',
#  'for',
#  'único',
#  'estaria',
#  'visto',
#  'simplesmente',
#  'geme',
#  'chamas',
#  'goles',
#  'dino',
#  'artes',
#  'centímetros',
#  'terceiro',
#  'esteja',
#  'iam',
#  'lembrou',
#  'dado',
#  'certa',
#  'anda',
#  'sensação',
#  'somente',
#  'sério',
#  'fôlego',
#  'daqui',
#  'soube',
#  'sentou',
#  'suponho',
#  'tivera',
#  'vários',
#  'essas',
#  'usava',
#  'ora',
#  'batendo',
#  'manter',
#  'normal',
#  'dinheiro',
#  'pássaro',
#  'invisibilidade',
#  'minhas',
#  'morte',
#  'seletor',
#  'retrato',
#  'fizeram',
#  'deixando',
#  'mandar',
#  'penas',
#  'escura',
#  'subiram',
#  'expulso',
#  'lista',
#  'mergulhou',
#  'quis',
#  'metade',
#  'tinta',
#  'pele',
#  'escapar',
#  'parava',
#  'através',
#  'ombros',
#  'concordou',
#  'explicar',
#  'filho',
#  'nova',
#  'sacudiu',
#  'espiou',
#  'alfeneiros',
#  'doze',
#  '2000',
#  'boxe',
#  'lorde',
#  'acham',
#  'apanhador',
#  'juntos',
#  'sprout',
#  'unicórnio',
#  'diz',
#  'precisamos',
#  'estação',
#  'seguro',
#  'buraco',
#  'saindo',
#  'morrer',
#  'pálido',
#  'pergaminho',
#  'som',
#  'tivessem',
#  'sentou-se',
#  'próxima',
#  'cobras',
#  'dormir',
#  'lançou',
#  'dúvida',
#  'desculpe',
#  'dizia',
#  'naquela',
#  'segunda',
#  'foto',
#  'exames',
#  'cabana',
#  'ouvidos',
#  'ala',
#  'velas',
#  'corvinal',
#  'cartão',
#  'desesperado',
#  'olivaras',
#  'pequena',
#  'esquerda',
#  'velocidade',
#  'dragões',
#  'varinhas',
#  'resmungou',
#  'indo',
#  'gaiola',
#  'responder',
#  'gosto',
#  'contente',
#  'verão',
#  'maneira',
#  'escondido',
#  'baixa',
#  'surpresa',
#  'rosnou',
#  'sentir',
#  'velha',
#  'perguntas',
#  'vidro',
#  'semanas',
#  'dava',
#  'minuto',
#  'negros',
#  'visão',
#  'coragem',
#  'sabem',
#  'usando',
#  'andava',
#  'distância',
#  'onze',
#  'escrivaninha',
#  'ronan',
#  'árvore',
#  'madeira',
#  'invisível',
#  'além',
#  'hooch',
#  'taça',
#  'vindo',
#  'segurando',
#  'sorriu',
#  'nela',
#  'chance',
#  'chave',
#  'fechou',
#  'impedir',
#  'várias',
#  'leve',
#  'entender',
#  'nisso',
#  'comida',
#  'correr',
#  'passando',
#  'diga',
#  'perna',
#  'trinta',
#  'altura',
#  'joelhos',
#  'rispidez',
#  'londres',
#  'observando',
#  'poderes',
#  'diferente',
#  'fica',
#  'espécie',
#  'próprio',
#  'alvo',
#  'via',
#  'pensei',
#  'deitar',
#  'rapidamente',
#  'jardim',
#  'oito',
#  'ataque',
#  'srta',
#  'terminou',
#  'fila',
#  'subir',
#  'barreira',
#  'pó',
#  'parecer',
#  'pois',
#  'multidão',
#  'ministério',
#  'branco',
#  'bilhete',
#  'estômago',
#  'vazia',
#  'dessas',
#  'espiando',
#  'ganhou',
#  'ofegou',
#  'lágrimas',
#  'animado',
#  'falava',
#  'deram',
#  'rir',
#  ...]

# %%
vetor_varinha = model.wv['varinha']

# %%
'harry' in model.wv
# Out:
# True

# %% [markdown]
# ### Palavras semelhantes

# %%
model.wv.most_similar('harry')
# Out:
# [('ele', 0.6944401860237122),
#  ('draco', 0.6829034686088562),
#  ('neville', 0.6787735819816589),
#  ('hermione', 0.6738376617431641),
#  ('mione', 0.6719188690185547),
#  ('quirrell', 0.647872805595398),
#  ('rony', 0.6282997131347656),
#  ('snape', 0.6087087392807007),
#  ('escapar', 0.6006371974945068),
#  ('riddle', 0.5969793200492859)]

# %%
model.wv.most_similar('voldemort')
# Out:
# [('descoberto', 0.8518000841140747),
#  ('morrer', 0.8400903344154358),
#  ('provavelmente', 0.8379504680633545),
#  ('flamel', 0.8374667167663574),
#  ('acontecer', 0.8324741125106812),
#  ('mim', 0.8267525434494019),
#  ('imaginar', 0.8251470327377319),
#  ('vovó', 0.8242557048797607),
#  ('nasceu', 0.8183131814002991),
#  ('espírito', 0.8174005746841431)]

# %%
print(model.wv.similarity('harry', 'snape'))
print(model.wv.similarity('harry', 'hagrid'))
print(model.wv.similarity('rony', 'hermione'))
print(model.wv.similarity('harry', 'draco'))
# Out:
# 0.6087087
# 0.5916136
# 0.69543016
# 0.6829034

# %%
# Pares de palavras do universo Harry Potter
pairs = [
    ('harry', 'rony'),          # Amigos (deve ter valor alto)
    ('harry', 'hermione'),     # Amigos (deve ter valor alto)
    ('harry', 'voldemort'),    # Inimigos (contextos diferentes ou semelhantes?)
    ('dumbledore', 'snape'),   # Professores
    ('varinha', 'vassoura'),   # Objetos mágicos
    ('grifinória', 'sonserina') # Casas (usa 'grifinória' e 'sonserina' se o livro for PT-BR)
]

for w1, w2 in pairs:
    print('%s \t %s \t% .2f' % (w1, w2, model.wv.similarity(w1,w2)))
# Out:
# harry 	 rony 	 0.63
# harry 	 hermione 	 0.67
# harry 	 voldemort 	 0.10
# dumbledore 	 snape 	 0.71
# varinha 	 vassoura 	 0.78
# grifinória 	 sonserina 	 0.88

# %% [markdown]
# ### Intruso

# %%
model.wv.doesnt_match(['harry', 'rony', 'hermione', 'draco']) #malfoy/draco
# Out:
# 'rony'

# %%
#model.wv.doesnt_match(['rony', 'fred', 'george', 'harry'])
model.wv.doesnt_match(['weasley', 'fred', 'rony', 'potter'])
# Out:
# 'rony'

# %%
model.wv.doesnt_match(['grifinória', 'sonserina', 'corvinal', 'lufa-lufa', 'vassoura'])
# Out:
# 'vassoura'

# %%
resultado = model.wv.most_similar(positive=['sonserina', 'harry'], negative=['grifinória'])
print("Harry - Grifinória + Sonserina =")
print(resultado)
# Out:
# Harry - Grifinória + Sonserina =
# [('ele', 0.7135258316993713), ('quirrell', 0.6934767365455627), ('snape', 0.6105272173881531), ('dobby', 0.5731765031814575), ('draco', 0.5729082226753235), ('ela', 0.5622590780258179), ('escapar', 0.5516489744186401), ('neville', 0.541796863079071), ('riddle', 0.527872622013092), ('hagrid', 0.5264891982078552)]

# %%
resultado = model.wv.most_similar(positive=['harry', 'malfoy'], negative=['potter'])
print("Harry - Potter + Malfoy")
print(resultado)
# Out:
# Harry - Potter + Malfoy
# [('neville', 0.718235969543457), ('draco', 0.6554227471351624), ('gritinho', 0.6170804500579834), ('colin', 0.6094428896903992), ('escapar', 0.605563223361969), ('repente', 0.5946520566940308), ('quirrell', 0.5754522085189819), ('hermione', 0.5747398734092712), ('lockhart', 0.5685665011405945), ('riddle', 0.5637841820716858)]

# %%
model.wv.most_similar("harry", topn=50)
# Out:
# [('ele', 0.6944401860237122),
#  ('draco', 0.6829034686088562),
#  ('neville', 0.6787735819816589),
#  ('hermione', 0.6738376617431641),
#  ('mione', 0.6719188690185547),
#  ('quirrell', 0.647872805595398),
#  ('rony', 0.6282997131347656),
#  ('snape', 0.6087087392807007),
#  ('escapar', 0.6006371974945068),
#  ('riddle', 0.5969793200492859),
#  ('dobby', 0.5937113761901855),
#  ('hagrid', 0.5916135907173157),
#  ('colin', 0.5810748338699341),
#  ('ela', 0.580898106098175),
#  ('dumbledore', 0.5783413052558899),
#  ('ansioso', 0.5545103549957275),
#  ('gina', 0.5444226861000061),
#  ('pirraça', 0.5407524108886719),
#  ('nervoso', 0.5404333472251892),
#  ('simas', 0.5387157201766968),
#  ('agarre-o', 0.5313906669616699),
#  ('percy', 0.5303518772125244),
#  ('wood', 0.5281105041503906),
#  ('desesperado', 0.5271193385124207),
#  ('mostrando-o', 0.5267385840415955),
#  ('garoto', 0.5261170268058777),
#  ('repente', 0.523173451423645),
#  ('vozinha', 0.519230842590332),
#  ('depressa', 0.5170008540153503),
#  ('engasgado', 0.5167021155357361),
#  ('ernie', 0.5061333775520325),
#  ('justino', 0.5058479309082031),
#  ('expelliarmus', 0.5039769411087036),
#  ('lockhart', 0.5006391406059265),
#  ('baixinho', 0.4986345171928406),
#  ('fôlego', 0.49832046031951904),
#  ('canino', 0.49687421321868896),
#  ('dino', 0.4964170753955841),
#  ('lentamente', 0.4948037564754486),
#  ('apontando', 0.4944401681423187),
#  ('boca', 0.48876726627349854),
#  ('abaixou-se', 0.4867725968360901),
#  ('dormir', 0.48638737201690674),
#  ('furioso', 0.48452839255332947),
#  ('príncipe', 0.4822410047054291),
#  ('centauro', 0.4816761910915375),
#  ('secando', 0.4799908399581909),
#  ('esguelha', 0.479208379983902),
#  ('distraído', 0.4778645634651184),
#  ('subir', 0.4768213927745819)]

# %% [markdown]
# ### Analogia

# %%
def analogy(x2,y1,x1):
    result = model.wv.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]

# %%
analogy('rony', 'draco', 'harry')
# Out:
# 'baixinho'

# %%
analogy('sonserina', 'lufa-lufa', 'grifinória')
# Out:
# 'corvinal'

# %%
analogy('escola', 'feitiço', 'varinha')
# Out:
# 'aluno'

# %%
analogy('lorde', 'snape', 'dumbledore')
# Out:
# 'imaginando'

# %% [markdown]
# ## MODELO 2

# %% [markdown]
# ##### TREINAR O MODELO

# %%
model2 = Word2Vec(sentences, vector_size=150, window=5, min_count=2, sg=1, epochs=20, workers=3)

# %%
model2.wv.save_word2vec_format('model2_harry.txt',binary=False)

# %%
len(model2.wv)
# Out:
# 6989

# %%
model2.wv.index_to_key
# Out:
# ['de',
#  'que',
#  'a',
#  'e',
#  'o',
#  'harry',
#  'não',
#  'para',
#  'um',
#  'se',
#  'uma',
#  'os',
#  'com',
#  'do',
#  'em',
#  'ele',
#  'da',
#  'disse',
#  'é',
#  'no',
#  'rony',
#  'na',
#  'você',
#  'mas',
#  'por',
#  'as',
#  'mais',
#  'estava',
#  'como',
#  'quando',
#  'eu',
#  'era',
#  'à',
#  'ao',
#  'muito',
#  'foi',
#  'hagrid',
#  'está',
#  'dos',
#  'coisa',
#  'hermione',
#  'sua',
#  'me',
#  'seu',
#  'eles',
#  'ela',
#  'bem',
#  'das',
#  'cabeça',
#  'olhos',
#  'isso',
#  'até',
#  'dumbledore',
#  'tinha',
#  'vez',
#  'perguntou',
#  'ter',
#  '=',
#  'sem',
#  'então',
#  'vai',
#  'só',
#  'ser',
#  'agora',
#  'snape',
#  'porta',
#  'potter',
#  'já',
#  'pelo',
#  'weasley',
#  'parecia',
#  'dois',
#  'fazer',
#  'vocês',
#  'nada',
#  'lockhart',
#  'voz',
#  'depois',
#  'dizer',
#  'todos',
#  'lhe',
#  'vamos',
#  'nunca',
#  'havia',
#  'alguma',
#  'seus',
#  'aqui',
#  'tão',
#  'pela',
#  'nem',
#  'dele',
#  'sr.',
#  'draco',
#  'fora',
#  'lado',
#  'nos',
#  'quase',
#  'estavam',
#  'mesmo',
#  'ainda',
#  'sala',
#  'tem',
#  'ver',
#  'grifinória',
#  'tempo',
#  'ah',
#  'quem',
#  'casa',
#  'tinham',
#  'porque',
#  'meu',
#  'sobre',
#  'onde',
#  'enquanto',
#  'grande',
#  'varinha',
#  'hogwarts',
#  'escola',
#  'duda',
#  'malfoy',
#  'tudo',
#  'antes',
#  'viu',
#  'senhor',
#  'sabe',
#  'outra',
#  'também',
#  'rosto',
#  'profa',
#  'ou',
#  'alunos',
#  'tio',
#  'todo',
#  'volta',
#  'deu',
#  'chão',
#  'lá',
#  'mione',
#  'válter',
#  'mão',
#  'cima',
#  'vou',
#  'dia',
#  'alto',
#  'dobby',
#  'neville',
#  'respondeu',
#  'melhor',
#  'ficou',
#  'alguém',
#  'dursley',
#  'depressa',
#  'fred',
#  'cara',
#  'fez',
#  'três',
#  'ninguém',
#  'hora',
#  'noite',
#  'frente',
#  'pode',
#  'riddle',
#  'acho',
#  'dentro',
#  'minha',
#  'sonserina',
#  'nas',
#  'sempre',
#  'carro',
#  'bom',
#  'jorge',
#  'gina',
#  'estar',
#  'aos',
#  'estou',
#  'falar',
#  'outro',
#  'olhar',
#  'sei',
#  'isto',
#  'pessoas',
#  'madame',
#  'pedra',
#  'filch',
#  'às',
#  'cada',
#  'ano',
#  'tivesse',
#  'quirrell',
#  'prof',
#  'ia',
#  'percy',
#  'lugar',
#  'saiu',
#  'meio',
#  'pouco',
#  'mesa',
#  'gritou',
#  'exclamou',
#  'talvez',
#  'tentando',
#  'começou',
#  'claro',
#  'direção',
#  'suas',
#  'quadribol',
#  'ar',
#  'falou',
#  'primeiro',
#  'fazendo',
#  'câmara',
#  'ali',
#  'dar',
#  'sra.',
#  'olhou',
#  'atrás',
#  'livros',
#  'toda',
#  'corredor',
#  'podia',
#  'ficar',
#  'num',
#  'assim',
#  'repente',
#  'garoto',
#  'vassoura',
#  'poderia',
#  'sabia',
#  'coisas',
#  'mundo',
#  'tenho',
#  'são',
#  'trouxas',
#  'nós',
#  'professor',
#  'boca',
#  'capa',
#  'chapéu',
#  'bruxo',
#  'estão',
#  'minerva',
#  'sido',
#  'embora',
#  'entre',
#  'vão',
#  'quero',
#  'cabelos',
#  'deles',
#  'vezes',
#  'aula',
#  'outros',
#  'contra',
#  'quanto',
#  'tia',
#  'gente',
#  'foram',
#  'eram',
#  'ouviu',
#  'mãos',
#  'teve',
#  'ir',
#  'cama',
#  'certeza',
#  'diário',
#  'petúnia',
#  'há',
#  'saber',
#  'hoje',
#  'menos',
#  'qualquer',
#  'magia',
#  'correndo',
#  'aí',
#  'pai',
#  'nome',
#  'pessoa',
#  'bruxos',
#  'teria',
#  'deve',
#  'passar',
#  'fosse',
#  'primeira',
#  'livro',
#  'mal',
#  'trás',
#  'seguinte',
#  'finalmente',
#  'abriu',
#  'duas',
#  'castelo',
#  'entrar',
#  'olhando',
#  'anos',
#  'parede',
#  'queria',
#  'caminho',
#  'mim',
#  'pelos',
#  'vida',
#  'numa',
#  'devia',
#  'temos',
#  'vestes',
#  'quer',
#  'tentou',
#  'realmente',
#  'aquela',
#  'logo',
#  'janela',
#  'segundo',
#  'carta',
#  'mcgonagall',
#  'voltar',
#  'nariz',
#  'será',
#  'sorriso',
#  'murta',
#  'força',
#  'família',
#  'espelho',
#  'sair',
#  'nenhum',
#  'time',
#  'uns',
#  'acha',
#  'bateu',
#  'parou',
#  'aquele',
#  'instante',
#  'tanto',
#  'sentiu',
#  'momento',
#  'menino',
#  'novo',
#  'tenha',
#  'manhã',
#  'minutos',
#  'conseguiu',
#  'pensar',
#  'floresta',
#  'quarto',
#  'posso',
#  'este',
#  'deixou',
#  'durante',
#  'salão',
#  'cobra',
#  'braço',
#  'voldemort',
#  'professora',
#  'passou',
#  'rua',
#  'cinco',
#  'goyle',
#  'pontos',
#  'sangue',
#  'mãe',
#  'seguida',
#  'alta',
#  'demais',
#  'essa',
#  'contar',
#  'luz',
#  'pés',
#  'silêncio',
#  'algum',
#  'quatro',
#  'pirraça',
#  'tom',
#  'seria',
#  'verdade',
#  'entrou',
#  'coruja',
#  'garotos',
#  'enorme',
#  'pé',
#  'apenas',
#  'caiu',
#  'murmurou',
#  'andar',
#  'olívio',
#  'secreta',
#  'sou',
#  'ouviram',
#  'continuou',
#  'estivesse',
#  'deixar',
#  'fazia',
#  'wood',
#  'favor',
#  'rúbeo',
#  'aconteceu',
#  'dando',
#  'baixo',
#  'todas',
#  'ouvir',
#  'encontrar',
#  'fogo',
#  'tarde',
#  'ideia',
#  'pensou',
#  'capítulo',
#  'crabbe',
#  'professores',
#  'atenção',
#  'escada',
#  'diante',
#  'banheiro',
#  'dela',
#  'desde',
#  'alguns',
#  'dez',
#  'corpo',
#  'mesma',
#  'chegar',
#  'disso',
#  'continuava',
#  'velho',
#  'pelas',
#  'naquele',
#  'slytherin',
#  'teto',
#  'difícil',
#  'história',
#  'poder',
#  'fim',
#  'nick',
#  'falando',
#  'pudesse',
#  'escuro',
#  'sim',
#  'chegou',
#  'parte',
#  'trem',
#  'pena',
#  'puxou',
#  'voltou',
#  'quê',
#  'pareceu',
#  'horas',
#  'costas',
#  'virou',
#  'maior',
#  'poção',
#  'olhe',
#  'amigos',
#  'armário',
#  'levantou',
#  'pernas',
#  'razão',
#  'seja',
#  'jogo',
#  'feitiço',
#  'feito',
#  'dizendo',
#  'modo',
#  'muita',
#  'tirou',
#  'canino',
#  'granger',
#  'dragão',
#  'cheio',
#  'boa',
#  'pareciam',
#  'ergueu',
#  'óculos',
#  'vira',
#  'balaço',
#  'trevas',
#  'cair',
#  'entrada',
#  'desapareceu',
#  'tornou',
#  'perto',
#  'esse',
#  'última',
#  'preciso',
#  'grandes',
#  'conseguia',
#  'jeito',
#  'ponta',
#  'achou',
#  'parar',
#  'nosso',
#  'colin',
#  'trasgo',
#  'saíram',
#  'biblioteca',
#  'caso',
#  'contou',
#  'certo',
#  'pomfrey',
#  'parecendo',
#  'esperando',
#  'levou',
#  'comprar',
#  'meia',
#  'comunal',
#  'poções',
#  'natal',
#  'aranhas',
#  'sob',
#  'matar',
#  'exatamente',
#  'medo',
#  'palavras',
#  'bruxas',
#  'campo',
#  'umas',
#  'cartas',
#  'lareira',
#  'ombro',
#  'sorte',
#  'mulher',
#  'longe',
#  'pensando',
#  'paredes',
#  'expressão',
#  'justino',
#  'aulas',
#  'mamãe',
#  'testa',
#  'qual',
#  'correu',
#  'andando',
#  'vista',
#  'vassouras',
#  'caldeirão',
#  'feitiços',
#  'tentar',
#  'entraram',
#  'forte',
#  'cadeira',
#  'ficaram',
#  'procurando',
#  'agarrou',
#  'dedos',
#  'homem',
#  'acrescentou',
#  'principal',
#  'estamos',
#  'amigo',
#  'berrou',
#  'pais',
#  'virou-se',
#  'nervoso',
#  'raiva',
#  'apanhou',
#  'descobrir',
#  'esta',
#  'nossa',
#  'simas',
#  'canto',
#  'perguntar',
#  'faz',
#  'querer',
#  'trabalho',
#  'soltou',
#  'braços',
#  'parece',
#  'acontecendo',
#  'último',
#  'gilderoy',
#  'fantasma',
#  'casas',
#  'gringotes',
#  'houve',
#  'sozinho',
#  'levar',
#  'sol',
#  'passado',
#  'feliz',
#  'precisa',
#  'porém',
#  'possível',
#  'nenhuma',
#  'cinquenta',
#  'lufa-lufa',
#  'direto',
#  'gostaria',
#  'banco',
#  'menor',
#  'ruído',
#  'única',
#  'encontrou',
#  'apareceu',
#  'coração',
#  'têm',
#  'parado',
#  'jamais',
#  'começar',
#  'imediatamente',
#  'tirar',
#  'furioso',
#  'cheia',
#  'pior',
#  'veio',
#  'inteira',
#  'rápido',
#  'cachorro',
#  'viram',
#  'chá',
#  'sentado',
#  'obrigado',
#  'elfo',
#  'festa',
#  'pomo',
#  'nor-r-ra',
#  'edwiges',
#  'cuidado',
#  'fundo',
#  'dor',
#  'embaixo',
#  'barulho',
#  'loja',
#  'vinha',
#  'vendo',
#  'cozinha',
#  'espero',
#  'acima',
#  'famoso',
#  'bolso',
#  'palavra',
#  'ler',
#  'podiam',
#  'basilisco',
#  'cochichou',
#  'passos',
#  'mágica',
#  'cor',
#  'salto',
#  'papai',
#  'resto',
#  'pequeno',
#  'tamanho',
#  'apontando',
#  'iria',
#  'meus',
#  'hum',
#  'voando',
#  'muitos',
#  'diretor',
#  'estranha',
#  'desta',
#  'flitwick',
#  'torre',
#  'dormitório',
#  'fofo',
#  'gêmeos',
#  'cabeças',
#  'ansioso',
#  'lados',
#  'comentou',
#  'chocolate',
#  'férias',
#  'classe',
#  'podem',
#  'cicatriz',
#  'podemos',
#  'horrível',
#  'semana',
#  'provavelmente',
#  'pôde',
#  'gato',
#  'própria',
#  'fawkes',
#  'herdeiro',
#  'perder',
#  'comigo',
#  'passaram',
#  'aberta',
#  'tomar',
#  'junto',
#  'outras',
#  'água',
#  'suficiente',
#  'chegaram',
#  'ruim',
#  'vermelho',
#  'mandou',
#  'aniversário',
#  'lembrar',
#  'vir',
#  'aposto',
#  'esperar',
#  'sorrindo',
#  'acabara',
#  'segundos',
#  'aquilo',
#  'estranho',
#  'céu',
#  'sete',
#  'seis',
#  'lúcio',
#  'saguão',
#  'aluno',
#  'tanta',
#  'sapo',
#  'dias',
#  'sentia',
#  'explicou',
#  'apanhar',
#  'ficando',
#  'abrir',
#  'problema',
#  'ouro',
#  'próximo',
#  'corujas',
#  'nove',
#  'mostrar',
#  'árvores',
#  'jogadores',
#  'garota',
#  'flamel',
#  'usar',
#  'si',
#  'portas',
#  'comer',
#  'longo',
#  'lentamente',
#  'muitas',
#  'debaixo',
#  'procurar',
#  'prata',
#  'jantar',
#  'você-sabe-quem',
#  'ouvi',
#  'algumas',
#  'exceto',
#  'acreditar',
#  'forma',
#  'norberto',
#  'pediu',
#  'carlinhos',
#  'dentes',
#  'vinte',
#  'verde',
#  'nele',
#  'sussurrou',
#  'vontade',
#  'vá',
#  'afinal',
#  'completamente',
#  'elas',
#  'número',
#  'reparou',
#  'enormes',
#  'tipo',
#  'língua',
#  'papel',
#  'ernie',
#  'partida',
#  'escuridão',
#  'corredores',
#  'monitor',
#  'ouviu-se',
#  'longa',
#  'caixa',
#  'janelas',
#  'envelope',
#  'acabado',
#  'começaram',
#  'baixinho',
#  'querido',
#  'meninos',
#  'precisava',
#  'pergunta',
#  'conta',
#  'inteiro',
#  'sinal',
#  'bastante',
#  'frio',
#  'orelhas',
#  'estivera',
#  'vi',
#  'trouxa',
#  'achava',
#  'percebeu',
#  'pescoço',
#  'presente',
#  'monstro',
#  'voar',
#  'morto',
#  'ouvido',
#  'plataforma',
#  'jogar',
#  'nimbus',
#  'mágicas',
#  'bruxa',
#  'aonde',
#  'café',
#  'leu',
#  'apontou',
#  'bater',
#  'grito',
#  'importante',
#  'for',
#  'único',
#  'estaria',
#  'visto',
#  'simplesmente',
#  'geme',
#  'chamas',
#  'goles',
#  'dino',
#  'artes',
#  'centímetros',
#  'terceiro',
#  'esteja',
#  'iam',
#  'lembrou',
#  'dado',
#  'certa',
#  'anda',
#  'sensação',
#  'somente',
#  'sério',
#  'fôlego',
#  'daqui',
#  'soube',
#  'sentou',
#  'suponho',
#  'tivera',
#  'vários',
#  'essas',
#  'usava',
#  'ora',
#  'batendo',
#  'manter',
#  'normal',
#  'dinheiro',
#  'pássaro',
#  'invisibilidade',
#  'minhas',
#  'morte',
#  'seletor',
#  'retrato',
#  'fizeram',
#  'deixando',
#  'mandar',
#  'penas',
#  'escura',
#  'subiram',
#  'expulso',
#  'lista',
#  'mergulhou',
#  'quis',
#  'metade',
#  'tinta',
#  'pele',
#  'escapar',
#  'parava',
#  'através',
#  'ombros',
#  'concordou',
#  'explicar',
#  'filho',
#  'nova',
#  'sacudiu',
#  'espiou',
#  'alfeneiros',
#  'doze',
#  '2000',
#  'boxe',
#  'lorde',
#  'acham',
#  'apanhador',
#  'juntos',
#  'sprout',
#  'unicórnio',
#  'diz',
#  'precisamos',
#  'estação',
#  'seguro',
#  'buraco',
#  'saindo',
#  'morrer',
#  'pálido',
#  'pergaminho',
#  'som',
#  'tivessem',
#  'sentou-se',
#  'próxima',
#  'cobras',
#  'dormir',
#  'lançou',
#  'dúvida',
#  'desculpe',
#  'dizia',
#  'naquela',
#  'segunda',
#  'foto',
#  'exames',
#  'cabana',
#  'ouvidos',
#  'ala',
#  'velas',
#  'corvinal',
#  'cartão',
#  'desesperado',
#  'olivaras',
#  'pequena',
#  'esquerda',
#  'velocidade',
#  'dragões',
#  'varinhas',
#  'resmungou',
#  'indo',
#  'gaiola',
#  'responder',
#  'gosto',
#  'contente',
#  'verão',
#  'maneira',
#  'escondido',
#  'baixa',
#  'surpresa',
#  'rosnou',
#  'sentir',
#  'velha',
#  'perguntas',
#  'vidro',
#  'semanas',
#  'dava',
#  'minuto',
#  'negros',
#  'visão',
#  'coragem',
#  'sabem',
#  'usando',
#  'andava',
#  'distância',
#  'onze',
#  'escrivaninha',
#  'ronan',
#  'árvore',
#  'madeira',
#  'invisível',
#  'além',
#  'hooch',
#  'taça',
#  'vindo',
#  'segurando',
#  'sorriu',
#  'nela',
#  'chance',
#  'chave',
#  'fechou',
#  'impedir',
#  'várias',
#  'leve',
#  'entender',
#  'nisso',
#  'comida',
#  'correr',
#  'passando',
#  'diga',
#  'perna',
#  'trinta',
#  'altura',
#  'joelhos',
#  'rispidez',
#  'londres',
#  'observando',
#  'poderes',
#  'diferente',
#  'fica',
#  'espécie',
#  'próprio',
#  'alvo',
#  'via',
#  'pensei',
#  'deitar',
#  'rapidamente',
#  'jardim',
#  'oito',
#  'ataque',
#  'srta',
#  'terminou',
#  'fila',
#  'subir',
#  'barreira',
#  'pó',
#  'parecer',
#  'pois',
#  'multidão',
#  'ministério',
#  'branco',
#  'bilhete',
#  'estômago',
#  'vazia',
#  'dessas',
#  'espiando',
#  'ganhou',
#  'ofegou',
#  'lágrimas',
#  'animado',
#  'falava',
#  'deram',
#  'rir',
#  ...]

# %%
vetor2_varinha = model2.wv['varinha']

# %%
'harry' in model2.wv
# Out:
# True

# %% [markdown]
# ##### Palavras Semelhantes

# %%
model2.wv.most_similar('harry')
# Out:
# [('abobado', 0.5932192206382751),
#  ('desesperado', 0.5769644379615784),
#  ('portão', 0.5748124122619629),
#  ('mudando', 0.5676656365394592),
#  ('firenze', 0.5600485801696777),
#  ('distraído', 0.5522260069847107),
#  ('sorrir', 0.5504167079925537),
#  ('encarando-o', 0.5459402799606323),
#  ('automaticamente', 0.5456914305686951),
#  ('incerto', 0.5425942540168762)]

# %%
print(model2.wv.similarity('harry', 'snape'))
# Out:
# 0.23819412

# %%
for w1, w2 in pairs:
    print('%s \t %s \t% .2f' % (w1, w2, model2.wv.similarity(w1,w2)))
# Out:
# harry 	 rony 	 0.50
# harry 	 hermione 	 0.18
# harry 	 voldemort 	 0.20
# dumbledore 	 snape 	 0.38
# varinha 	 vassoura 	 0.46
# grifinória 	 sonserina 	 0.64

# %% [markdown]
# ##### Intruso

# %%
model2.wv.doesnt_match(['harry', 'rony', 'hermione', 'draco'])
# Out:
# 'hermione'

# %%
resultado = model2.wv.most_similar(positive=['harry', 'malfoy'], negative=['potter'])
print("Harry - Potter + Malfoy")
print(resultado)
# Out:
# Harry - Potter + Malfoy
# [('draco', 0.5102008581161499), ('lúcio', 0.4647396504878998), ('abobado', 0.4639739394187927), ('desdém', 0.46105679869651794), ('assustado', 0.4557773470878601), ('aliviado', 0.4470183253288269), ('baixando', 0.44240811467170715), ('amarrada', 0.4400467574596405), ('esticando-se', 0.43507814407348633), ('erguendo', 0.43388113379478455)]

# %%
model2.wv.most_similar("harry", topn=50)
# Out:
# [('abobado', 0.5932192206382751),
#  ('desesperado', 0.5769644379615784),
#  ('portão', 0.5748124122619629),
#  ('mudando', 0.5676656365394592),
#  ('firenze', 0.5600485801696777),
#  ('distraído', 0.5522260069847107),
#  ('sorrir', 0.5504167079925537),
#  ('encarando-o', 0.5459402799606323),
#  ('automaticamente', 0.5456914305686951),
#  ('incerto', 0.5425942540168762),
#  ('mexa', 0.5424286127090454),
#  ('chocada', 0.5400413274765015),
#  ('esticando-se', 0.5399340391159058),
#  ('expelliarmus', 0.539677619934082),
#  ('virando-se', 0.538231611251831),
#  ('abaixou-se', 0.5377339124679565),
#  ('pensativa', 0.5376068353652954),
#  ('aliviado', 0.5363860130310059),
#  ('tremer', 0.5358574390411377),
#  ('autorização', 0.5332087278366089),
#  ('enojado', 0.5324451327323914),
#  ('impaciente', 0.5319439768791199),
#  ('urgência', 0.5317479372024536),
#  ('sonolento', 0.5310287475585938),
#  ('pressuroso', 0.5299938321113586),
#  ('consultando', 0.5298993587493896),
#  ('contava', 0.5298605561256409),
#  ('engasgado', 0.5293764472007751),
#  ('ansiosa', 0.5292447209358215),
#  ('alohomora', 0.5280758142471313),
#  ('enchendo-se', 0.5277014970779419),
#  ('radiante', 0.5272239446640015),
#  ('cujos', 0.5270056128501892),
#  ('aterrorizado', 0.5269931554794312),
#  ('energia', 0.5251529812812805),
#  ('observando-a', 0.5243982076644897),
#  ('incrédulo', 0.5233121514320374),
#  ('grato', 0.5224192142486572),
#  ('abaixando-se', 0.5220276713371277),
#  ('aplaudir', 0.5205385088920593),
#  ('distinguir', 0.5204671621322632),
#  ('horário', 0.5197181105613708),
#  ('deitou', 0.5195733904838562),
#  ('mostrando-o', 0.5194507837295532),
#  ('observando-o', 0.5192714929580688),
#  ('esganiçando', 0.5187909007072449),
#  ('lívido', 0.5182608366012573),
#  ('alucinado', 0.5174064636230469),
#  ('intrigado', 0.5169883966445923),
#  ('corando', 0.5167982578277588)]

# %% [markdown]
# #### Analogia

# %%
def analogy2(x2,y1,x1):
    result = model2.wv.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]

# %%
analogy2('escola', 'feitiço', 'varinha')
# Out:
# 'setembro'

# %% [markdown]
# ## MODELO 3

# %% [markdown]
# ##### TREINAR O MODELO

# %%
model3 = Word2Vec(sentences, vector_size=150, window=2, sg=0, min_count=2, epochs=20)

# %%
model3.wv.save_word2vec_format('model3_harry.txt',binary=False)

# %%
len(model3.wv)
# Out:
# 6989

# %%
model3.wv.index_to_key
# Out:
# ['de',
#  'que',
#  'a',
#  'e',
#  'o',
#  'harry',
#  'não',
#  'para',
#  'um',
#  'se',
#  'uma',
#  'os',
#  'com',
#  'do',
#  'em',
#  'ele',
#  'da',
#  'disse',
#  'é',
#  'no',
#  'rony',
#  'na',
#  'você',
#  'mas',
#  'por',
#  'as',
#  'mais',
#  'estava',
#  'como',
#  'quando',
#  'eu',
#  'era',
#  'à',
#  'ao',
#  'muito',
#  'foi',
#  'hagrid',
#  'está',
#  'dos',
#  'coisa',
#  'hermione',
#  'sua',
#  'me',
#  'seu',
#  'eles',
#  'ela',
#  'bem',
#  'das',
#  'cabeça',
#  'olhos',
#  'isso',
#  'até',
#  'dumbledore',
#  'tinha',
#  'vez',
#  'perguntou',
#  'ter',
#  '=',
#  'sem',
#  'então',
#  'vai',
#  'só',
#  'ser',
#  'agora',
#  'snape',
#  'porta',
#  'potter',
#  'já',
#  'pelo',
#  'weasley',
#  'parecia',
#  'dois',
#  'fazer',
#  'vocês',
#  'nada',
#  'lockhart',
#  'voz',
#  'depois',
#  'dizer',
#  'todos',
#  'lhe',
#  'vamos',
#  'nunca',
#  'havia',
#  'alguma',
#  'seus',
#  'aqui',
#  'tão',
#  'pela',
#  'nem',
#  'dele',
#  'sr.',
#  'draco',
#  'fora',
#  'lado',
#  'nos',
#  'quase',
#  'estavam',
#  'mesmo',
#  'ainda',
#  'sala',
#  'tem',
#  'ver',
#  'grifinória',
#  'tempo',
#  'ah',
#  'quem',
#  'casa',
#  'tinham',
#  'porque',
#  'meu',
#  'sobre',
#  'onde',
#  'enquanto',
#  'grande',
#  'varinha',
#  'hogwarts',
#  'escola',
#  'duda',
#  'malfoy',
#  'tudo',
#  'antes',
#  'viu',
#  'senhor',
#  'sabe',
#  'outra',
#  'também',
#  'rosto',
#  'profa',
#  'ou',
#  'alunos',
#  'tio',
#  'todo',
#  'volta',
#  'deu',
#  'chão',
#  'lá',
#  'mione',
#  'válter',
#  'mão',
#  'cima',
#  'vou',
#  'dia',
#  'alto',
#  'dobby',
#  'neville',
#  'respondeu',
#  'melhor',
#  'ficou',
#  'alguém',
#  'dursley',
#  'depressa',
#  'fred',
#  'cara',
#  'fez',
#  'três',
#  'ninguém',
#  'hora',
#  'noite',
#  'frente',
#  'pode',
#  'riddle',
#  'acho',
#  'dentro',
#  'minha',
#  'sonserina',
#  'nas',
#  'sempre',
#  'carro',
#  'bom',
#  'jorge',
#  'gina',
#  'estar',
#  'aos',
#  'estou',
#  'falar',
#  'outro',
#  'olhar',
#  'sei',
#  'isto',
#  'pessoas',
#  'madame',
#  'pedra',
#  'filch',
#  'às',
#  'cada',
#  'ano',
#  'tivesse',
#  'quirrell',
#  'prof',
#  'ia',
#  'percy',
#  'lugar',
#  'saiu',
#  'meio',
#  'pouco',
#  'mesa',
#  'gritou',
#  'exclamou',
#  'talvez',
#  'tentando',
#  'começou',
#  'claro',
#  'direção',
#  'suas',
#  'quadribol',
#  'ar',
#  'falou',
#  'primeiro',
#  'fazendo',
#  'câmara',
#  'ali',
#  'dar',
#  'sra.',
#  'olhou',
#  'atrás',
#  'livros',
#  'toda',
#  'corredor',
#  'podia',
#  'ficar',
#  'num',
#  'assim',
#  'repente',
#  'garoto',
#  'vassoura',
#  'poderia',
#  'sabia',
#  'coisas',
#  'mundo',
#  'tenho',
#  'são',
#  'trouxas',
#  'nós',
#  'professor',
#  'boca',
#  'capa',
#  'chapéu',
#  'bruxo',
#  'estão',
#  'minerva',
#  'sido',
#  'embora',
#  'entre',
#  'vão',
#  'quero',
#  'cabelos',
#  'deles',
#  'vezes',
#  'aula',
#  'outros',
#  'contra',
#  'quanto',
#  'tia',
#  'gente',
#  'foram',
#  'eram',
#  'ouviu',
#  'mãos',
#  'teve',
#  'ir',
#  'cama',
#  'certeza',
#  'diário',
#  'petúnia',
#  'há',
#  'saber',
#  'hoje',
#  'menos',
#  'qualquer',
#  'magia',
#  'correndo',
#  'aí',
#  'pai',
#  'nome',
#  'pessoa',
#  'bruxos',
#  'teria',
#  'deve',
#  'passar',
#  'fosse',
#  'primeira',
#  'livro',
#  'mal',
#  'trás',
#  'seguinte',
#  'finalmente',
#  'abriu',
#  'duas',
#  'castelo',
#  'entrar',
#  'olhando',
#  'anos',
#  'parede',
#  'queria',
#  'caminho',
#  'mim',
#  'pelos',
#  'vida',
#  'numa',
#  'devia',
#  'temos',
#  'vestes',
#  'quer',
#  'tentou',
#  'realmente',
#  'aquela',
#  'logo',
#  'janela',
#  'segundo',
#  'carta',
#  'mcgonagall',
#  'voltar',
#  'nariz',
#  'será',
#  'sorriso',
#  'murta',
#  'força',
#  'família',
#  'espelho',
#  'sair',
#  'nenhum',
#  'time',
#  'uns',
#  'acha',
#  'bateu',
#  'parou',
#  'aquele',
#  'instante',
#  'tanto',
#  'sentiu',
#  'momento',
#  'menino',
#  'novo',
#  'tenha',
#  'manhã',
#  'minutos',
#  'conseguiu',
#  'pensar',
#  'floresta',
#  'quarto',
#  'posso',
#  'este',
#  'deixou',
#  'durante',
#  'salão',
#  'cobra',
#  'braço',
#  'voldemort',
#  'professora',
#  'passou',
#  'rua',
#  'cinco',
#  'goyle',
#  'pontos',
#  'sangue',
#  'mãe',
#  'seguida',
#  'alta',
#  'demais',
#  'essa',
#  'contar',
#  'luz',
#  'pés',
#  'silêncio',
#  'algum',
#  'quatro',
#  'pirraça',
#  'tom',
#  'seria',
#  'verdade',
#  'entrou',
#  'coruja',
#  'garotos',
#  'enorme',
#  'pé',
#  'apenas',
#  'caiu',
#  'murmurou',
#  'andar',
#  'olívio',
#  'secreta',
#  'sou',
#  'ouviram',
#  'continuou',
#  'estivesse',
#  'deixar',
#  'fazia',
#  'wood',
#  'favor',
#  'rúbeo',
#  'aconteceu',
#  'dando',
#  'baixo',
#  'todas',
#  'ouvir',
#  'encontrar',
#  'fogo',
#  'tarde',
#  'ideia',
#  'pensou',
#  'capítulo',
#  'crabbe',
#  'professores',
#  'atenção',
#  'escada',
#  'diante',
#  'banheiro',
#  'dela',
#  'desde',
#  'alguns',
#  'dez',
#  'corpo',
#  'mesma',
#  'chegar',
#  'disso',
#  'continuava',
#  'velho',
#  'pelas',
#  'naquele',
#  'slytherin',
#  'teto',
#  'difícil',
#  'história',
#  'poder',
#  'fim',
#  'nick',
#  'falando',
#  'pudesse',
#  'escuro',
#  'sim',
#  'chegou',
#  'parte',
#  'trem',
#  'pena',
#  'puxou',
#  'voltou',
#  'quê',
#  'pareceu',
#  'horas',
#  'costas',
#  'virou',
#  'maior',
#  'poção',
#  'olhe',
#  'amigos',
#  'armário',
#  'levantou',
#  'pernas',
#  'razão',
#  'seja',
#  'jogo',
#  'feitiço',
#  'feito',
#  'dizendo',
#  'modo',
#  'muita',
#  'tirou',
#  'canino',
#  'granger',
#  'dragão',
#  'cheio',
#  'boa',
#  'pareciam',
#  'ergueu',
#  'óculos',
#  'vira',
#  'balaço',
#  'trevas',
#  'cair',
#  'entrada',
#  'desapareceu',
#  'tornou',
#  'perto',
#  'esse',
#  'última',
#  'preciso',
#  'grandes',
#  'conseguia',
#  'jeito',
#  'ponta',
#  'achou',
#  'parar',
#  'nosso',
#  'colin',
#  'trasgo',
#  'saíram',
#  'biblioteca',
#  'caso',
#  'contou',
#  'certo',
#  'pomfrey',
#  'parecendo',
#  'esperando',
#  'levou',
#  'comprar',
#  'meia',
#  'comunal',
#  'poções',
#  'natal',
#  'aranhas',
#  'sob',
#  'matar',
#  'exatamente',
#  'medo',
#  'palavras',
#  'bruxas',
#  'campo',
#  'umas',
#  'cartas',
#  'lareira',
#  'ombro',
#  'sorte',
#  'mulher',
#  'longe',
#  'pensando',
#  'paredes',
#  'expressão',
#  'justino',
#  'aulas',
#  'mamãe',
#  'testa',
#  'qual',
#  'correu',
#  'andando',
#  'vista',
#  'vassouras',
#  'caldeirão',
#  'feitiços',
#  'tentar',
#  'entraram',
#  'forte',
#  'cadeira',
#  'ficaram',
#  'procurando',
#  'agarrou',
#  'dedos',
#  'homem',
#  'acrescentou',
#  'principal',
#  'estamos',
#  'amigo',
#  'berrou',
#  'pais',
#  'virou-se',
#  'nervoso',
#  'raiva',
#  'apanhou',
#  'descobrir',
#  'esta',
#  'nossa',
#  'simas',
#  'canto',
#  'perguntar',
#  'faz',
#  'querer',
#  'trabalho',
#  'soltou',
#  'braços',
#  'parece',
#  'acontecendo',
#  'último',
#  'gilderoy',
#  'fantasma',
#  'casas',
#  'gringotes',
#  'houve',
#  'sozinho',
#  'levar',
#  'sol',
#  'passado',
#  'feliz',
#  'precisa',
#  'porém',
#  'possível',
#  'nenhuma',
#  'cinquenta',
#  'lufa-lufa',
#  'direto',
#  'gostaria',
#  'banco',
#  'menor',
#  'ruído',
#  'única',
#  'encontrou',
#  'apareceu',
#  'coração',
#  'têm',
#  'parado',
#  'jamais',
#  'começar',
#  'imediatamente',
#  'tirar',
#  'furioso',
#  'cheia',
#  'pior',
#  'veio',
#  'inteira',
#  'rápido',
#  'cachorro',
#  'viram',
#  'chá',
#  'sentado',
#  'obrigado',
#  'elfo',
#  'festa',
#  'pomo',
#  'nor-r-ra',
#  'edwiges',
#  'cuidado',
#  'fundo',
#  'dor',
#  'embaixo',
#  'barulho',
#  'loja',
#  'vinha',
#  'vendo',
#  'cozinha',
#  'espero',
#  'acima',
#  'famoso',
#  'bolso',
#  'palavra',
#  'ler',
#  'podiam',
#  'basilisco',
#  'cochichou',
#  'passos',
#  'mágica',
#  'cor',
#  'salto',
#  'papai',
#  'resto',
#  'pequeno',
#  'tamanho',
#  'apontando',
#  'iria',
#  'meus',
#  'hum',
#  'voando',
#  'muitos',
#  'diretor',
#  'estranha',
#  'desta',
#  'flitwick',
#  'torre',
#  'dormitório',
#  'fofo',
#  'gêmeos',
#  'cabeças',
#  'ansioso',
#  'lados',
#  'comentou',
#  'chocolate',
#  'férias',
#  'classe',
#  'podem',
#  'cicatriz',
#  'podemos',
#  'horrível',
#  'semana',
#  'provavelmente',
#  'pôde',
#  'gato',
#  'própria',
#  'fawkes',
#  'herdeiro',
#  'perder',
#  'comigo',
#  'passaram',
#  'aberta',
#  'tomar',
#  'junto',
#  'outras',
#  'água',
#  'suficiente',
#  'chegaram',
#  'ruim',
#  'vermelho',
#  'mandou',
#  'aniversário',
#  'lembrar',
#  'vir',
#  'aposto',
#  'esperar',
#  'sorrindo',
#  'acabara',
#  'segundos',
#  'aquilo',
#  'estranho',
#  'céu',
#  'sete',
#  'seis',
#  'lúcio',
#  'saguão',
#  'aluno',
#  'tanta',
#  'sapo',
#  'dias',
#  'sentia',
#  'explicou',
#  'apanhar',
#  'ficando',
#  'abrir',
#  'problema',
#  'ouro',
#  'próximo',
#  'corujas',
#  'nove',
#  'mostrar',
#  'árvores',
#  'jogadores',
#  'garota',
#  'flamel',
#  'usar',
#  'si',
#  'portas',
#  'comer',
#  'longo',
#  'lentamente',
#  'muitas',
#  'debaixo',
#  'procurar',
#  'prata',
#  'jantar',
#  'você-sabe-quem',
#  'ouvi',
#  'algumas',
#  'exceto',
#  'acreditar',
#  'forma',
#  'norberto',
#  'pediu',
#  'carlinhos',
#  'dentes',
#  'vinte',
#  'verde',
#  'nele',
#  'sussurrou',
#  'vontade',
#  'vá',
#  'afinal',
#  'completamente',
#  'elas',
#  'número',
#  'reparou',
#  'enormes',
#  'tipo',
#  'língua',
#  'papel',
#  'ernie',
#  'partida',
#  'escuridão',
#  'corredores',
#  'monitor',
#  'ouviu-se',
#  'longa',
#  'caixa',
#  'janelas',
#  'envelope',
#  'acabado',
#  'começaram',
#  'baixinho',
#  'querido',
#  'meninos',
#  'precisava',
#  'pergunta',
#  'conta',
#  'inteiro',
#  'sinal',
#  'bastante',
#  'frio',
#  'orelhas',
#  'estivera',
#  'vi',
#  'trouxa',
#  'achava',
#  'percebeu',
#  'pescoço',
#  'presente',
#  'monstro',
#  'voar',
#  'morto',
#  'ouvido',
#  'plataforma',
#  'jogar',
#  'nimbus',
#  'mágicas',
#  'bruxa',
#  'aonde',
#  'café',
#  'leu',
#  'apontou',
#  'bater',
#  'grito',
#  'importante',
#  'for',
#  'único',
#  'estaria',
#  'visto',
#  'simplesmente',
#  'geme',
#  'chamas',
#  'goles',
#  'dino',
#  'artes',
#  'centímetros',
#  'terceiro',
#  'esteja',
#  'iam',
#  'lembrou',
#  'dado',
#  'certa',
#  'anda',
#  'sensação',
#  'somente',
#  'sério',
#  'fôlego',
#  'daqui',
#  'soube',
#  'sentou',
#  'suponho',
#  'tivera',
#  'vários',
#  'essas',
#  'usava',
#  'ora',
#  'batendo',
#  'manter',
#  'normal',
#  'dinheiro',
#  'pássaro',
#  'invisibilidade',
#  'minhas',
#  'morte',
#  'seletor',
#  'retrato',
#  'fizeram',
#  'deixando',
#  'mandar',
#  'penas',
#  'escura',
#  'subiram',
#  'expulso',
#  'lista',
#  'mergulhou',
#  'quis',
#  'metade',
#  'tinta',
#  'pele',
#  'escapar',
#  'parava',
#  'através',
#  'ombros',
#  'concordou',
#  'explicar',
#  'filho',
#  'nova',
#  'sacudiu',
#  'espiou',
#  'alfeneiros',
#  'doze',
#  '2000',
#  'boxe',
#  'lorde',
#  'acham',
#  'apanhador',
#  'juntos',
#  'sprout',
#  'unicórnio',
#  'diz',
#  'precisamos',
#  'estação',
#  'seguro',
#  'buraco',
#  'saindo',
#  'morrer',
#  'pálido',
#  'pergaminho',
#  'som',
#  'tivessem',
#  'sentou-se',
#  'próxima',
#  'cobras',
#  'dormir',
#  'lançou',
#  'dúvida',
#  'desculpe',
#  'dizia',
#  'naquela',
#  'segunda',
#  'foto',
#  'exames',
#  'cabana',
#  'ouvidos',
#  'ala',
#  'velas',
#  'corvinal',
#  'cartão',
#  'desesperado',
#  'olivaras',
#  'pequena',
#  'esquerda',
#  'velocidade',
#  'dragões',
#  'varinhas',
#  'resmungou',
#  'indo',
#  'gaiola',
#  'responder',
#  'gosto',
#  'contente',
#  'verão',
#  'maneira',
#  'escondido',
#  'baixa',
#  'surpresa',
#  'rosnou',
#  'sentir',
#  'velha',
#  'perguntas',
#  'vidro',
#  'semanas',
#  'dava',
#  'minuto',
#  'negros',
#  'visão',
#  'coragem',
#  'sabem',
#  'usando',
#  'andava',
#  'distância',
#  'onze',
#  'escrivaninha',
#  'ronan',
#  'árvore',
#  'madeira',
#  'invisível',
#  'além',
#  'hooch',
#  'taça',
#  'vindo',
#  'segurando',
#  'sorriu',
#  'nela',
#  'chance',
#  'chave',
#  'fechou',
#  'impedir',
#  'várias',
#  'leve',
#  'entender',
#  'nisso',
#  'comida',
#  'correr',
#  'passando',
#  'diga',
#  'perna',
#  'trinta',
#  'altura',
#  'joelhos',
#  'rispidez',
#  'londres',
#  'observando',
#  'poderes',
#  'diferente',
#  'fica',
#  'espécie',
#  'próprio',
#  'alvo',
#  'via',
#  'pensei',
#  'deitar',
#  'rapidamente',
#  'jardim',
#  'oito',
#  'ataque',
#  'srta',
#  'terminou',
#  'fila',
#  'subir',
#  'barreira',
#  'pó',
#  'parecer',
#  'pois',
#  'multidão',
#  'ministério',
#  'branco',
#  'bilhete',
#  'estômago',
#  'vazia',
#  'dessas',
#  'espiando',
#  'ganhou',
#  'ofegou',
#  'lágrimas',
#  'animado',
#  'falava',
#  'deram',
#  'rir',
#  ...]

# %%
vetor3_varinha = model3.wv['varinha']

# %%
'harry' in model3.wv
# Out:
# True

# %% [markdown]
# #### Palavras Semelhantes

# %%
model3.wv.most_similar('harry')
# Out:
# [('abobado', 0.5346392393112183),
#  ('observando-a', 0.5161057114601135),
#  ('expelliarmus', 0.5120424032211304),
#  ('mudando', 0.5085846781730652),
#  ('portão', 0.5081167817115784),
#  ('horrorizado', 0.5070067048072815),
#  ('apoiando-se', 0.5063827633857727),
#  ('tremer', 0.5050144195556641),
#  ('automaticamente', 0.5047757029533386),
#  ('puxá-la', 0.5040197968482971)]

# %%
print(model3.wv.similarity('harry', 'snape'))
# Out:
# 0.14408745

# %%
for w1, w2 in pairs:
    print('%s \t %s \t% .2f' % (w1, w2, model3.wv.similarity(w1,w2)))
# Out:
# harry 	 rony 	 0.43
# harry 	 hermione 	 0.14
# harry 	 voldemort 	 0.22
# dumbledore 	 snape 	 0.23
# varinha 	 vassoura 	 0.31
# grifinória 	 sonserina 	 0.55

# %% [markdown]
# #### Intruso

# %%
model3.wv.doesnt_match(['harry', 'rony', 'hermione', 'draco'])
# Out:
# 'hermione'

# %%
resultado = model3.wv.most_similar(positive=['harry', 'malfoy'], negative=['potter'])
print("Harry - Potter + Malfoy")
print(resultado)
# Out:
# Harry - Potter + Malfoy
# [('lúcio', 0.45086801052093506), ('rolaram', 0.4454335868358612), ('draco', 0.44337594509124756), ('horrorizado', 0.43659332394599915), ('desdém', 0.43041694164276123), ('amarrada', 0.41930264234542847), ('incapaz', 0.41495752334594727), ('murros', 0.4147757291793823), ('olho', 0.41382506489753723), ('desdenhoso', 0.4123585820198059)]

# %%
model3.wv.most_similar("harry", topn=50)
# Out:
# [('abobado', 0.5346392393112183),
#  ('observando-a', 0.5161057114601135),
#  ('expelliarmus', 0.5120424032211304),
#  ('mudando', 0.5085846781730652),
#  ('portão', 0.5081167817115784),
#  ('horrorizado', 0.5070067048072815),
#  ('apoiando-se', 0.5063827633857727),
#  ('tremer', 0.5050144195556641),
#  ('automaticamente', 0.5047757029533386),
#  ('puxá-la', 0.5040197968482971),
#  ('pensativa', 0.4999939799308777),
#  ('encarando-o', 0.49902600049972534),
#  ('grunhiu', 0.498165100812912),
#  ('observando-o', 0.49815547466278076),
#  ('virou-a', 0.4975093901157379),
#  ('chocada', 0.49519726634025574),
#  ('mostrando-o', 0.49470096826553345),
#  ('esticando-se', 0.49453508853912354),
#  ('desesperado', 0.49257346987724304),
#  ('enchendo-se', 0.49255603551864624),
#  ('pegando', 0.4917353391647339),
#  ('súbita', 0.4911435544490814),
#  ('aplaudir', 0.49099820852279663),
#  ('excitada', 0.48925861716270447),
#  ('sonolento', 0.48910248279571533),
#  ('abaixou-se', 0.48897412419319153),
#  ('aterrorizado', 0.48776185512542725),
#  ('mexa', 0.48700737953186035),
#  ('enojado', 0.48683586716651917),
#  ('distraído', 0.4865042567253113),
#  ('febrilmente', 0.48587048053741455),
#  ('êxtase', 0.4858056604862213),
#  ('irmãzinha', 0.4853355288505554),
#  ('esganiçando', 0.4843372106552124),
#  ('alucinado', 0.48395535349845886),
#  ('tábua', 0.4835931658744812),
#  ('brandindo', 0.4834624230861664),
#  ('implicar', 0.4833274483680725),
#  ('alohomora', 0.48325827717781067),
#  ('incrédulo', 0.4829975962638855),
#  ('distinguir', 0.4824412763118744),
#  ('travesseiros', 0.4819868505001068),
#  ('desapontado', 0.48103317618370056),
#  ('indignado', 0.480612188577652),
#  ('zangar', 0.47993865609169006),
#  ('berro', 0.47975555062294006),
#  ('incerto', 0.47957977652549744),
#  ('agarrou-o', 0.47941678762435913),
#  ('facilidade', 0.4793035089969635),
#  ('conseguindo', 0.47851571440696716)]

# %% [markdown]
# #### Analogia

# %%
def analogy3(x2,y1,x1):
    result = model3.wv.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]

# %%
analogy3('escola', 'feitiço', 'varinha')
# Out:
# 'expulso'

# %% [markdown]
# ## MODELO 4

# %% [markdown]
# #### TREINAR O MODELO

# %%
model4 = Word2Vec(sentences, vector_size=300, window=10, sg=1, min_count=2, epochs=20)

# %%
model4.wv.save_word2vec_format('model4_harry.txt',binary=False)

# %%
len(model4.wv)
# Out:
# 6989

# %%
model4.wv.index_to_key
# Out:
# ['de',
#  'que',
#  'a',
#  'e',
#  'o',
#  'harry',
#  'não',
#  'para',
#  'um',
#  'se',
#  'uma',
#  'os',
#  'com',
#  'do',
#  'em',
#  'ele',
#  'da',
#  'disse',
#  'é',
#  'no',
#  'rony',
#  'na',
#  'você',
#  'mas',
#  'por',
#  'as',
#  'mais',
#  'estava',
#  'como',
#  'quando',
#  'eu',
#  'era',
#  'à',
#  'ao',
#  'muito',
#  'foi',
#  'hagrid',
#  'está',
#  'dos',
#  'coisa',
#  'hermione',
#  'sua',
#  'me',
#  'seu',
#  'eles',
#  'ela',
#  'bem',
#  'das',
#  'cabeça',
#  'olhos',
#  'isso',
#  'até',
#  'dumbledore',
#  'tinha',
#  'vez',
#  'perguntou',
#  'ter',
#  '=',
#  'sem',
#  'então',
#  'vai',
#  'só',
#  'ser',
#  'agora',
#  'snape',
#  'porta',
#  'potter',
#  'já',
#  'pelo',
#  'weasley',
#  'parecia',
#  'dois',
#  'fazer',
#  'vocês',
#  'nada',
#  'lockhart',
#  'voz',
#  'depois',
#  'dizer',
#  'todos',
#  'lhe',
#  'vamos',
#  'nunca',
#  'havia',
#  'alguma',
#  'seus',
#  'aqui',
#  'tão',
#  'pela',
#  'nem',
#  'dele',
#  'sr.',
#  'draco',
#  'fora',
#  'lado',
#  'nos',
#  'quase',
#  'estavam',
#  'mesmo',
#  'ainda',
#  'sala',
#  'tem',
#  'ver',
#  'grifinória',
#  'tempo',
#  'ah',
#  'quem',
#  'casa',
#  'tinham',
#  'porque',
#  'meu',
#  'sobre',
#  'onde',
#  'enquanto',
#  'grande',
#  'varinha',
#  'hogwarts',
#  'escola',
#  'duda',
#  'malfoy',
#  'tudo',
#  'antes',
#  'viu',
#  'senhor',
#  'sabe',
#  'outra',
#  'também',
#  'rosto',
#  'profa',
#  'ou',
#  'alunos',
#  'tio',
#  'todo',
#  'volta',
#  'deu',
#  'chão',
#  'lá',
#  'mione',
#  'válter',
#  'mão',
#  'cima',
#  'vou',
#  'dia',
#  'alto',
#  'dobby',
#  'neville',
#  'respondeu',
#  'melhor',
#  'ficou',
#  'alguém',
#  'dursley',
#  'depressa',
#  'fred',
#  'cara',
#  'fez',
#  'três',
#  'ninguém',
#  'hora',
#  'noite',
#  'frente',
#  'pode',
#  'riddle',
#  'acho',
#  'dentro',
#  'minha',
#  'sonserina',
#  'nas',
#  'sempre',
#  'carro',
#  'bom',
#  'jorge',
#  'gina',
#  'estar',
#  'aos',
#  'estou',
#  'falar',
#  'outro',
#  'olhar',
#  'sei',
#  'isto',
#  'pessoas',
#  'madame',
#  'pedra',
#  'filch',
#  'às',
#  'cada',
#  'ano',
#  'tivesse',
#  'quirrell',
#  'prof',
#  'ia',
#  'percy',
#  'lugar',
#  'saiu',
#  'meio',
#  'pouco',
#  'mesa',
#  'gritou',
#  'exclamou',
#  'talvez',
#  'tentando',
#  'começou',
#  'claro',
#  'direção',
#  'suas',
#  'quadribol',
#  'ar',
#  'falou',
#  'primeiro',
#  'fazendo',
#  'câmara',
#  'ali',
#  'dar',
#  'sra.',
#  'olhou',
#  'atrás',
#  'livros',
#  'toda',
#  'corredor',
#  'podia',
#  'ficar',
#  'num',
#  'assim',
#  'repente',
#  'garoto',
#  'vassoura',
#  'poderia',
#  'sabia',
#  'coisas',
#  'mundo',
#  'tenho',
#  'são',
#  'trouxas',
#  'nós',
#  'professor',
#  'boca',
#  'capa',
#  'chapéu',
#  'bruxo',
#  'estão',
#  'minerva',
#  'sido',
#  'embora',
#  'entre',
#  'vão',
#  'quero',
#  'cabelos',
#  'deles',
#  'vezes',
#  'aula',
#  'outros',
#  'contra',
#  'quanto',
#  'tia',
#  'gente',
#  'foram',
#  'eram',
#  'ouviu',
#  'mãos',
#  'teve',
#  'ir',
#  'cama',
#  'certeza',
#  'diário',
#  'petúnia',
#  'há',
#  'saber',
#  'hoje',
#  'menos',
#  'qualquer',
#  'magia',
#  'correndo',
#  'aí',
#  'pai',
#  'nome',
#  'pessoa',
#  'bruxos',
#  'teria',
#  'deve',
#  'passar',
#  'fosse',
#  'primeira',
#  'livro',
#  'mal',
#  'trás',
#  'seguinte',
#  'finalmente',
#  'abriu',
#  'duas',
#  'castelo',
#  'entrar',
#  'olhando',
#  'anos',
#  'parede',
#  'queria',
#  'caminho',
#  'mim',
#  'pelos',
#  'vida',
#  'numa',
#  'devia',
#  'temos',
#  'vestes',
#  'quer',
#  'tentou',
#  'realmente',
#  'aquela',
#  'logo',
#  'janela',
#  'segundo',
#  'carta',
#  'mcgonagall',
#  'voltar',
#  'nariz',
#  'será',
#  'sorriso',
#  'murta',
#  'força',
#  'família',
#  'espelho',
#  'sair',
#  'nenhum',
#  'time',
#  'uns',
#  'acha',
#  'bateu',
#  'parou',
#  'aquele',
#  'instante',
#  'tanto',
#  'sentiu',
#  'momento',
#  'menino',
#  'novo',
#  'tenha',
#  'manhã',
#  'minutos',
#  'conseguiu',
#  'pensar',
#  'floresta',
#  'quarto',
#  'posso',
#  'este',
#  'deixou',
#  'durante',
#  'salão',
#  'cobra',
#  'braço',
#  'voldemort',
#  'professora',
#  'passou',
#  'rua',
#  'cinco',
#  'goyle',
#  'pontos',
#  'sangue',
#  'mãe',
#  'seguida',
#  'alta',
#  'demais',
#  'essa',
#  'contar',
#  'luz',
#  'pés',
#  'silêncio',
#  'algum',
#  'quatro',
#  'pirraça',
#  'tom',
#  'seria',
#  'verdade',
#  'entrou',
#  'coruja',
#  'garotos',
#  'enorme',
#  'pé',
#  'apenas',
#  'caiu',
#  'murmurou',
#  'andar',
#  'olívio',
#  'secreta',
#  'sou',
#  'ouviram',
#  'continuou',
#  'estivesse',
#  'deixar',
#  'fazia',
#  'wood',
#  'favor',
#  'rúbeo',
#  'aconteceu',
#  'dando',
#  'baixo',
#  'todas',
#  'ouvir',
#  'encontrar',
#  'fogo',
#  'tarde',
#  'ideia',
#  'pensou',
#  'capítulo',
#  'crabbe',
#  'professores',
#  'atenção',
#  'escada',
#  'diante',
#  'banheiro',
#  'dela',
#  'desde',
#  'alguns',
#  'dez',
#  'corpo',
#  'mesma',
#  'chegar',
#  'disso',
#  'continuava',
#  'velho',
#  'pelas',
#  'naquele',
#  'slytherin',
#  'teto',
#  'difícil',
#  'história',
#  'poder',
#  'fim',
#  'nick',
#  'falando',
#  'pudesse',
#  'escuro',
#  'sim',
#  'chegou',
#  'parte',
#  'trem',
#  'pena',
#  'puxou',
#  'voltou',
#  'quê',
#  'pareceu',
#  'horas',
#  'costas',
#  'virou',
#  'maior',
#  'poção',
#  'olhe',
#  'amigos',
#  'armário',
#  'levantou',
#  'pernas',
#  'razão',
#  'seja',
#  'jogo',
#  'feitiço',
#  'feito',
#  'dizendo',
#  'modo',
#  'muita',
#  'tirou',
#  'canino',
#  'granger',
#  'dragão',
#  'cheio',
#  'boa',
#  'pareciam',
#  'ergueu',
#  'óculos',
#  'vira',
#  'balaço',
#  'trevas',
#  'cair',
#  'entrada',
#  'desapareceu',
#  'tornou',
#  'perto',
#  'esse',
#  'última',
#  'preciso',
#  'grandes',
#  'conseguia',
#  'jeito',
#  'ponta',
#  'achou',
#  'parar',
#  'nosso',
#  'colin',
#  'trasgo',
#  'saíram',
#  'biblioteca',
#  'caso',
#  'contou',
#  'certo',
#  'pomfrey',
#  'parecendo',
#  'esperando',
#  'levou',
#  'comprar',
#  'meia',
#  'comunal',
#  'poções',
#  'natal',
#  'aranhas',
#  'sob',
#  'matar',
#  'exatamente',
#  'medo',
#  'palavras',
#  'bruxas',
#  'campo',
#  'umas',
#  'cartas',
#  'lareira',
#  'ombro',
#  'sorte',
#  'mulher',
#  'longe',
#  'pensando',
#  'paredes',
#  'expressão',
#  'justino',
#  'aulas',
#  'mamãe',
#  'testa',
#  'qual',
#  'correu',
#  'andando',
#  'vista',
#  'vassouras',
#  'caldeirão',
#  'feitiços',
#  'tentar',
#  'entraram',
#  'forte',
#  'cadeira',
#  'ficaram',
#  'procurando',
#  'agarrou',
#  'dedos',
#  'homem',
#  'acrescentou',
#  'principal',
#  'estamos',
#  'amigo',
#  'berrou',
#  'pais',
#  'virou-se',
#  'nervoso',
#  'raiva',
#  'apanhou',
#  'descobrir',
#  'esta',
#  'nossa',
#  'simas',
#  'canto',
#  'perguntar',
#  'faz',
#  'querer',
#  'trabalho',
#  'soltou',
#  'braços',
#  'parece',
#  'acontecendo',
#  'último',
#  'gilderoy',
#  'fantasma',
#  'casas',
#  'gringotes',
#  'houve',
#  'sozinho',
#  'levar',
#  'sol',
#  'passado',
#  'feliz',
#  'precisa',
#  'porém',
#  'possível',
#  'nenhuma',
#  'cinquenta',
#  'lufa-lufa',
#  'direto',
#  'gostaria',
#  'banco',
#  'menor',
#  'ruído',
#  'única',
#  'encontrou',
#  'apareceu',
#  'coração',
#  'têm',
#  'parado',
#  'jamais',
#  'começar',
#  'imediatamente',
#  'tirar',
#  'furioso',
#  'cheia',
#  'pior',
#  'veio',
#  'inteira',
#  'rápido',
#  'cachorro',
#  'viram',
#  'chá',
#  'sentado',
#  'obrigado',
#  'elfo',
#  'festa',
#  'pomo',
#  'nor-r-ra',
#  'edwiges',
#  'cuidado',
#  'fundo',
#  'dor',
#  'embaixo',
#  'barulho',
#  'loja',
#  'vinha',
#  'vendo',
#  'cozinha',
#  'espero',
#  'acima',
#  'famoso',
#  'bolso',
#  'palavra',
#  'ler',
#  'podiam',
#  'basilisco',
#  'cochichou',
#  'passos',
#  'mágica',
#  'cor',
#  'salto',
#  'papai',
#  'resto',
#  'pequeno',
#  'tamanho',
#  'apontando',
#  'iria',
#  'meus',
#  'hum',
#  'voando',
#  'muitos',
#  'diretor',
#  'estranha',
#  'desta',
#  'flitwick',
#  'torre',
#  'dormitório',
#  'fofo',
#  'gêmeos',
#  'cabeças',
#  'ansioso',
#  'lados',
#  'comentou',
#  'chocolate',
#  'férias',
#  'classe',
#  'podem',
#  'cicatriz',
#  'podemos',
#  'horrível',
#  'semana',
#  'provavelmente',
#  'pôde',
#  'gato',
#  'própria',
#  'fawkes',
#  'herdeiro',
#  'perder',
#  'comigo',
#  'passaram',
#  'aberta',
#  'tomar',
#  'junto',
#  'outras',
#  'água',
#  'suficiente',
#  'chegaram',
#  'ruim',
#  'vermelho',
#  'mandou',
#  'aniversário',
#  'lembrar',
#  'vir',
#  'aposto',
#  'esperar',
#  'sorrindo',
#  'acabara',
#  'segundos',
#  'aquilo',
#  'estranho',
#  'céu',
#  'sete',
#  'seis',
#  'lúcio',
#  'saguão',
#  'aluno',
#  'tanta',
#  'sapo',
#  'dias',
#  'sentia',
#  'explicou',
#  'apanhar',
#  'ficando',
#  'abrir',
#  'problema',
#  'ouro',
#  'próximo',
#  'corujas',
#  'nove',
#  'mostrar',
#  'árvores',
#  'jogadores',
#  'garota',
#  'flamel',
#  'usar',
#  'si',
#  'portas',
#  'comer',
#  'longo',
#  'lentamente',
#  'muitas',
#  'debaixo',
#  'procurar',
#  'prata',
#  'jantar',
#  'você-sabe-quem',
#  'ouvi',
#  'algumas',
#  'exceto',
#  'acreditar',
#  'forma',
#  'norberto',
#  'pediu',
#  'carlinhos',
#  'dentes',
#  'vinte',
#  'verde',
#  'nele',
#  'sussurrou',
#  'vontade',
#  'vá',
#  'afinal',
#  'completamente',
#  'elas',
#  'número',
#  'reparou',
#  'enormes',
#  'tipo',
#  'língua',
#  'papel',
#  'ernie',
#  'partida',
#  'escuridão',
#  'corredores',
#  'monitor',
#  'ouviu-se',
#  'longa',
#  'caixa',
#  'janelas',
#  'envelope',
#  'acabado',
#  'começaram',
#  'baixinho',
#  'querido',
#  'meninos',
#  'precisava',
#  'pergunta',
#  'conta',
#  'inteiro',
#  'sinal',
#  'bastante',
#  'frio',
#  'orelhas',
#  'estivera',
#  'vi',
#  'trouxa',
#  'achava',
#  'percebeu',
#  'pescoço',
#  'presente',
#  'monstro',
#  'voar',
#  'morto',
#  'ouvido',
#  'plataforma',
#  'jogar',
#  'nimbus',
#  'mágicas',
#  'bruxa',
#  'aonde',
#  'café',
#  'leu',
#  'apontou',
#  'bater',
#  'grito',
#  'importante',
#  'for',
#  'único',
#  'estaria',
#  'visto',
#  'simplesmente',
#  'geme',
#  'chamas',
#  'goles',
#  'dino',
#  'artes',
#  'centímetros',
#  'terceiro',
#  'esteja',
#  'iam',
#  'lembrou',
#  'dado',
#  'certa',
#  'anda',
#  'sensação',
#  'somente',
#  'sério',
#  'fôlego',
#  'daqui',
#  'soube',
#  'sentou',
#  'suponho',
#  'tivera',
#  'vários',
#  'essas',
#  'usava',
#  'ora',
#  'batendo',
#  'manter',
#  'normal',
#  'dinheiro',
#  'pássaro',
#  'invisibilidade',
#  'minhas',
#  'morte',
#  'seletor',
#  'retrato',
#  'fizeram',
#  'deixando',
#  'mandar',
#  'penas',
#  'escura',
#  'subiram',
#  'expulso',
#  'lista',
#  'mergulhou',
#  'quis',
#  'metade',
#  'tinta',
#  'pele',
#  'escapar',
#  'parava',
#  'através',
#  'ombros',
#  'concordou',
#  'explicar',
#  'filho',
#  'nova',
#  'sacudiu',
#  'espiou',
#  'alfeneiros',
#  'doze',
#  '2000',
#  'boxe',
#  'lorde',
#  'acham',
#  'apanhador',
#  'juntos',
#  'sprout',
#  'unicórnio',
#  'diz',
#  'precisamos',
#  'estação',
#  'seguro',
#  'buraco',
#  'saindo',
#  'morrer',
#  'pálido',
#  'pergaminho',
#  'som',
#  'tivessem',
#  'sentou-se',
#  'próxima',
#  'cobras',
#  'dormir',
#  'lançou',
#  'dúvida',
#  'desculpe',
#  'dizia',
#  'naquela',
#  'segunda',
#  'foto',
#  'exames',
#  'cabana',
#  'ouvidos',
#  'ala',
#  'velas',
#  'corvinal',
#  'cartão',
#  'desesperado',
#  'olivaras',
#  'pequena',
#  'esquerda',
#  'velocidade',
#  'dragões',
#  'varinhas',
#  'resmungou',
#  'indo',
#  'gaiola',
#  'responder',
#  'gosto',
#  'contente',
#  'verão',
#  'maneira',
#  'escondido',
#  'baixa',
#  'surpresa',
#  'rosnou',
#  'sentir',
#  'velha',
#  'perguntas',
#  'vidro',
#  'semanas',
#  'dava',
#  'minuto',
#  'negros',
#  'visão',
#  'coragem',
#  'sabem',
#  'usando',
#  'andava',
#  'distância',
#  'onze',
#  'escrivaninha',
#  'ronan',
#  'árvore',
#  'madeira',
#  'invisível',
#  'além',
#  'hooch',
#  'taça',
#  'vindo',
#  'segurando',
#  'sorriu',
#  'nela',
#  'chance',
#  'chave',
#  'fechou',
#  'impedir',
#  'várias',
#  'leve',
#  'entender',
#  'nisso',
#  'comida',
#  'correr',
#  'passando',
#  'diga',
#  'perna',
#  'trinta',
#  'altura',
#  'joelhos',
#  'rispidez',
#  'londres',
#  'observando',
#  'poderes',
#  'diferente',
#  'fica',
#  'espécie',
#  'próprio',
#  'alvo',
#  'via',
#  'pensei',
#  'deitar',
#  'rapidamente',
#  'jardim',
#  'oito',
#  'ataque',
#  'srta',
#  'terminou',
#  'fila',
#  'subir',
#  'barreira',
#  'pó',
#  'parecer',
#  'pois',
#  'multidão',
#  'ministério',
#  'branco',
#  'bilhete',
#  'estômago',
#  'vazia',
#  'dessas',
#  'espiando',
#  'ganhou',
#  'ofegou',
#  'lágrimas',
#  'animado',
#  'falava',
#  'deram',
#  'rir',
#  ...]

# %%
vetor4_varinha = model4.wv['varinha']

# %%
'harry' in model4.wv
# Out:
# True

# %% [markdown]
# #### Palavras Semelhantes

# %%
model4.wv.most_similar('harry')
# Out:
# [('abobado', 0.5526439547538757),
#  ('pressuroso', 0.5150402188301086),
#  ('observando-a', 0.5123217701911926),
#  ('enchendo-se', 0.5074033737182617),
#  ('mexa', 0.504151463508606),
#  ('incerto', 0.5034191012382507),
#  ('distraído', 0.5032956600189209),
#  ('chocada', 0.5021492838859558),
#  ('desesperado', 0.5013585090637207),
#  ('apoiando-se', 0.5007676482200623)]

# %%
print(model4.wv.similarity('harry', 'snape'))
# Out:
# 0.13139978

# %%
for w1, w2 in pairs:
    print('%s \t %s \t% .2f' % (w1, w2, model4.wv.similarity(w1,w2)))
# Out:
# harry 	 rony 	 0.44
# harry 	 hermione 	 0.13
# harry 	 voldemort 	 0.20
# dumbledore 	 snape 	 0.24
# varinha 	 vassoura 	 0.30
# grifinória 	 sonserina 	 0.50

# %% [markdown]
# #### Intruso

# %%
model4.wv.doesnt_match(['harry', 'rony', 'hermione', 'draco'])
# Out:
# 'draco'

# %%
resultado = model4.wv.most_similar(positive=['harry', 'malfoy'], negative=['potter'])
print("Harry - Potter + Malfoy")
print(resultado)
# Out:
# Harry - Potter + Malfoy
# [('rolaram', 0.4546729326248169), ('incapaz', 0.43246179819107056), ('lúcio', 0.42959946393966675), ('sorrisinho', 0.4243828356266022), ('sacudiam', 0.4219605028629303), ('horrorizado', 0.42192572355270386), ('abobado', 0.4204128682613373), ('erguendo', 0.4173361361026764), ('pressuroso', 0.4108964800834656), ('cutucou', 0.40736013650894165)]

# %%
model4.wv.most_similar("harry", topn=50)
# Out:
# [('abobado', 0.5526439547538757),
#  ('pressuroso', 0.5150402188301086),
#  ('observando-a', 0.5123217701911926),
#  ('enchendo-se', 0.5074033737182617),
#  ('mexa', 0.504151463508606),
#  ('incerto', 0.5034191012382507),
#  ('distraído', 0.5032956600189209),
#  ('chocada', 0.5021492838859558),
#  ('desesperado', 0.5013585090637207),
#  ('apoiando-se', 0.5007676482200623),
#  ('irmãzinha', 0.4998050332069397),
#  ('boquiabriu-se', 0.49980252981185913),
#  ('solte', 0.4994572103023529),
#  ('expelliarmus', 0.49854129552841187),
#  ('enojado', 0.4975385069847107),
#  ('pensativa', 0.4972607493400574),
#  ('indignado', 0.4959943890571594),
#  ('aplaudir', 0.4948100745677948),
#  ('intrigado', 0.49445176124572754),
#  ('tremer', 0.49311795830726624),
#  ('berro', 0.49299687147140503),
#  ('virando-se', 0.4922636151313782),
#  ('encarando-o', 0.4914824366569519),
#  ('portão', 0.4914461076259613),
#  ('deprimido', 0.49032750725746155),
#  ('esganiçando', 0.48984143137931824),
#  ('facilidade', 0.4897416830062866),
#  ('puxá-la', 0.48863139748573303),
#  ('mostrando-o', 0.48785707354545593),
#  ('mudando', 0.48725202679634094),
#  ('distinguir', 0.4872313439846039),
#  ('sorrir', 0.4868117868900299),
#  ('esticando-se', 0.4862086772918701),
#  ('aliviado', 0.48600396513938904),
#  ('recorte', 0.4852196276187897),
#  ('caramba', 0.4838963449001312),
#  ('automaticamente', 0.482819527387619),
#  ('curta', 0.4823411703109741),
#  ('fazê-lo', 0.480904757976532),
#  ('coitado', 0.4799465835094452),
#  ('vigiar', 0.4798917770385742),
#  ('zangar', 0.4797240197658539),
#  ('verso', 0.4788501262664795),
#  ('sonolento', 0.47873708605766296),
#  ('rasgá-lo', 0.4787125885486603),
#  ('desapontado', 0.47854524850845337),
#  ('desvencilhar', 0.47798386216163635),
#  ('alohomora', 0.4778614938259125),
#  ('observando-o', 0.4775249660015106),
#  ('alucinado', 0.47714298963546753)]

# %% [markdown]
# #### Analogia

# %%
def analogy4(x2,y1,x1):
    result = model4.wv.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]

# %%
analogy4('escola', 'feitiço', 'varinha')
# Out:
# 'passei'

# %% [markdown]
# ## Conclusão

# %%
palavra_teste = "vassoura"

print(f"Vizinhos de '{palavra_teste}':")
print("M1 (Standard):", [w for w, s in model.wv.most_similar(palavra_teste, topn=3)])
print("M2 (Skip-Gram):", [w for w, s in model2.wv.most_similar(palavra_teste, topn=3)])
print("M3 (Janela Curta):", [w for w, s in model3.wv.most_similar(palavra_teste, topn=3)])
print("M4 (Contexto Largo):", [w for w, s in model4.wv.most_similar(palavra_teste, topn=3)])
# Out:
# Vizinhos de 'vassoura':
# M1 (Standard): ['página', 'carta', 'carteira']
# M2 (Skip-Gram): ['montou', 'desmontar', 'mochila']
# M3 (Janela Curta): ['nimbus', '2000', 'montar']
# M4 (Contexto Largo): ['nimbus', '2000', 'montar']
